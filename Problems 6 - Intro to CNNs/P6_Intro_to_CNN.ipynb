# %% [markdown]
# # Introduction to Convolutional Neural Networks

# %% [markdown]
# In this notebook we will see how to define and use a Convolutional Neural Network (CNN) for clasifying images.
#
# Contrary to the MLPs we have used up to know, where each unit connects to all the units of the previous layer, a unit in a convoutional layer only "sees" a small region of the layer before, and applies a filter - a local operation - on this small region. The key idea is to apply this same filter to the whole image in a grid fashion, which results into a map of activations for this filter. Using many filters, results into a set of activation maps that when stacked together will form the output of the convolutional layer (each activation map corresponding to a "channel" for the next layer).
#
# Typically, convolutions are followed by pooling layers that reduce the dimensionality of our intermedate result, and give us every time a little bit more of viewpoint invariance (at the cost of losing precise information about the location of things).
#
# When dealing with images, our inputs, and all intermediate tensors we produce through convolution layers will be 3-dimensional tensors. And if we vectorise our operations and pass a whole batch of images in a single go, we will be dealing with 4-dimensional tensors. The ordering of the dimensions in pytorch is $(BatchSize \times nChannels \times Height \times Width)$.
#
# After a series of convolutions and pooling operations, we typically want to flaten the images. The flattening operation collapses an array into a 1-dimensional vector. For example, if we have a tensor of $20 \times 5 \times 5$ $(C \times H \times W)$, its flattened version is a 1d vector of $500$ values. Now we can feed these $500$ values into a MLP for classifiying the image.

# %%
import torch #should be installed by default in any colab notebook
import numpy as np
import matplotlib.pyplot as plt
from IPython import display
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
import matplotlib.pyplot as plt

# %%
# If this cell fails you need to change the runtime of your colab notebook to GPU
# Go to Runtime -> Change Runtime Type and select GPU
assert torch.cuda.is_available(), "GPU is not enabled"

# use gpu if available
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

# %%
def get_n_params(model, learnable_only=True):
  """Utility function to count the number of parameters in a model"""
  n_params = [p.numel() for p in model.parameters() if (p.requires_grad or not(learnable_only))]
  return sum(n_params)

# %% [markdown]
# # Data
#
# Before training we need data! For this notebook we will use the FashionMNIST dataset. Which is available in [torchvision](https://pytorch.org/vision/stable/index.html)

# %%
train_set = datasets.FashionMNIST("data", train=True, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.2860,), (0.3205,)),
                                                                                                   transforms.RandomHorizontalFlip()]))
val_set = datasets.FashionMNIST("data", train=False, download=True, transform=transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.2860,), (0.3205,))]))

train_loader = torch.utils.data.DataLoader(train_set, batch_size=256, shuffle=True, num_workers=2)
val_loader = torch.utils.data.DataLoader(val_set, batch_size=512, shuffle=False, num_workers=2)
# Out:
# 100%|██████████| 26.4M/26.4M [00:03<00:00, 7.87MB/s]
# 100%|██████████| 29.5k/29.5k [00:00<00:00, 168kB/s]
# 100%|██████████| 4.42M/4.42M [00:01<00:00, 3.13MB/s]
# 100%|██████████| 5.15k/5.15k [00:00<00:00, 13.0MB/s]

# %% [markdown]
# ---
# DataLoader: It calls Dataset.__getitem__() and inside we have a function that is getfunction that if it has any transformation it transforms it:
#
#
#     if self.transform
#         self.transforms()
#
#
#
# ---

# %% [markdown]
# The images of FashionMNIST are of size $(28 \times 28)$ pixels, and have a single channel - the greyscale one. So they are given as a 2D tensor. You can easily check this:

# %%
img = train_set.data[0]
img.shape
# Out:
# torch.Size([28, 28])

# %% [markdown]
# ## Filters and Convolutional layers

# %% [markdown]
# To define a CNN model, similarly to the MLP case, we need to define all the operations and then combine them into the forward pass. Apart from `nn.Linear()` layers, we will now use `nn.Conv2d()` layers, which correspond to 2D convolutions.
#
# To perform a convolution, we need to define the size of our filters, and how many filters to use.
#
# The size of the filter is given by its width and height (which will be equal), and the number of channels which has to be the same as the number of channels of the input it will be applied to. So, if `in_channels` is the number of channels of the input, and `kernel_size` is the width and height of our filter, then our filter will be a tensor of shape $(in\_channels \times kernel\_size \times kernel\_size)$.
#
# The other piece of information needed is how many filters to use. Remember that each filter gives rise to one activation map, which in turn corresponds to one channel in the output. So the number of filters to use is the same as the number of output channels (`out_channels`) we want to have.
#
# Internally, the set of weights that represent all the filters of a convolutional layer is stored as a single 4D tensor of shape (Number of filters, Number of channels, Height, Width), which would be equivalently $(out\_channels \times in\_channels \times kernel\_size \times kernel\_size)$
#
# This is the minimum information needed to define a convolution layer. Unless otherwise specified, this would apply a default padding of zero and stride of 1. Have a look at the documentation for more details on the `nn.Conv2d()` layer.
#
# https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html?highlight=conv#torch.nn.Conv2d
#
# Finally, remember the formula to calculate the size of the output $o$ given the input size $n$ the filter size $f$ the padding $p$ and the stride $s$:
#
# $o = {\frac {(n + 2p - f)} s} + 1$

# %% [markdown]
# <br>
# <span style="color: blue">
#
# **Exercise 1**: Given the following convolutional layer:
#
# `nn.Conv2d(in_channels=20, out_channels=128, kernel_size=3)`
#
# What is the shape of the weights and biases of the convolutional layer?
#
# </span>

# %% [markdown]
# ---
# In a convolutional layer, the weights are stored in a 4D tensor with the shape **(out_channels (number of kernels), in_channels, kernel_size, kernel_size)**. Given the data provided, the weight tensor will have a shape of **(128, 20, 3, 3)**.
#
# The biases are stored in a 1D tensor, where each output channel has a single bias term. Since the layer has **128 output channels**, the bias tensor will have a shape of **(128)**.  So, we have 128 biases as there is 1 bias for each layer.
#
# ---

# %% [markdown]
# ![IMG_5195.jpg](data:image/jpeg;base64,...)

# %%
# To prove my answer
myConv= nn.Conv2d(in_channels=20, out_channels=128, kernel_size=3)
print(myConv.weight.shape)
print(myConv.bias.shape)
# Out:
# torch.Size([128, 20, 3, 3])
# torch.Size([128])

# %% [markdown]
# ## Our Convolutional Model

# %% [markdown]
# Let's define now our first CNN model.

# %%
class CNN(nn.Module):
    def __init__(self, n_feature, output_size):
        super(CNN, self).__init__()
        self.n_feature = n_feature
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=n_feature, kernel_size = 5)
        self.conv2 = nn.Conv2d(n_feature, n_feature, kernel_size=5)
        self.fc1 = nn.Linear(n_feature, 50) #ERROR
        self.fc2 = nn.Linear(50, 10)
        self.maxpool = nn.MaxPool2d(kernel_size=2)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.maxpool(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.maxpool(x)
        x = x.view(-1, self.n_feature) #ERROR
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# <font color="blue">**Exercise 2**: The model defined above has a shape mismatch problem. Calculate the correct input dimension for `fc1` and change its definition in the `__init__()` method and the call to `x.view()` in the forward pass. </font>

# %% [markdown]
# ---
#
# We determine the feature map size after each convolutional and pooling layer, given that the input image size is 28 x 28. The first convolutional layer (`conv1`) applies a 5 x 5 kernel, reducing the spatial dimensions to 24 x 24, followed by a 2 x 2 max pooling operation, which further downsamples it to 12 x 12. The second convolutional layer (`conv2`) again applies a 5 x 5 kernel, reducing the feature map size to 8 x 8, and another 2 x 2 max pooling operation further reduces it to 4 x 4. This means that before entering the fully connected layer (`fc1`), the feature map shape is **(n_feature, 4, 4)**, which must be properly flattened for further processing.
#
#
# ---

# %% [markdown]
# ![IMG_5197.jpg](data:image/jpeg;base64,...)

# %%
# Your Code Here
class CNN(nn.Module):
    def __init__(self, n_feature, output_size):
        super(CNN, self).__init__()
        self.n_feature = n_feature
        self.conv1 = nn.Conv2d(in_channels=1, out_channels=n_feature, kernel_size=5)
        self.conv2 = nn.Conv2d(n_feature, n_feature, kernel_size=5)
        self.fc1 = nn.Linear(n_feature * 4 * 4, 50)  # Fixed input size
        self.fc2 = nn.Linear(50, output_size)
        self.maxpool = nn.MaxPool2d(kernel_size=2)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = self.maxpool(x)
        x = self.conv2(x)
        x = F.relu(x)
        x = self.maxpool(x)
        x = x.view(-1, self.n_feature * 4 * 4)  # Fixed view size
        x = self.fc1(x)
        x = F.relu(x)
        x = self.fc2(x)
        return x

# %% [markdown]
# ## Hyperparameters

# %% [markdown]
# To use our CNN we need to create our model and define our hyperparameters. We will use an output size of 10, as there are 10 classes in FashionMNIST, and we will train with cross entropy loss and stochastic gradient descent.

# %%
torch.backends.cudnn.benchmark = True
learning_rate = 1e-2
lambda_l2 = 1e-5
momentum = 0.5
torch.manual_seed(0) # seed for reproductibility

output_size = 10  # there are 10 classes

model = CNN(6, output_size)

print(f"Number of parameters: {get_n_params(model)}")

# move model to gpu if available
model.to(device)

# nn package also has different loss functions.
# we use cross entropy loss for our classification task
criterion = torch.nn.CrossEntropyLoss() # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html#torch.nn.CrossEntropyLoss

# we use the optim package to apply
# stochastic gradient descent for our parameter updates
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=lambda_l2) # built-in L2
# Out:
# Number of parameters: 6422

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 3**: What does the line `torch.backends.cudnn.benchmark = True` do? How will it affect our runtime if the size of the input images vary a lot?</font>
#
# > Hint: Have a look at https://pytorch.org/docs/stable/backends.html
#
# </span>

# %% [markdown]
# ---
#
# The line `torch.backends.cudnn.benchmark = True` optimizes the selection of convolution algorithms in CuDNN to improve runtime efficiency. It works best when input sizes are consistent, as it allows CuDNN to select and cache the fastest convolution algorithm for a given configuration. However, if input image sizes vary significantly, this can lead to inefficient runtime behavior since the model will repeatedly search for the optimal algorithm, potentially slowing down performance instead of improving it.
#
# ---

# %% [markdown]
# ## Training and Validation

# %% [markdown]
# We should also define our training and validation loops. These are similar to previous notebooks.

# %%
@torch.no_grad()  # prevent this function from computing gradients
def validate(criterion, model, loader):

    val_loss = 0
    correct = 0

    model.eval()

    for data, target in loader:

        data, target = data.to(device), target.to(device)

        output = model(data)
        loss = criterion(output, target)
        val_loss += loss.item()
        pred = output.data.max(1, keepdim=True)[1] # get the index of the max logit
        correct += pred.eq(target.view_as(pred)).sum().item()

    val_loss /= len(loader.dataset)
    accuracy = 100. * correct / len(loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        val_loss, correct, len(loader.dataset), accuracy))


    return val_loss


def train(epoch, criterion, model, optimizer, loader):

    total_loss = 0.0

    model.train()

    for batch_idx, (data, target) in enumerate(loader):

        optimizer.zero_grad()

        data, target = data.to(device), target.to(device)

        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(loader.dataset),
                100. * batch_idx / len(loader), loss.item()))


        total_loss += loss.item()  #.item() is very important here? Why?

    return total_loss / len(loader.dataset)

# %% [markdown]
# ### Run Training

# %%
losses = {"train": [], "val": []}
for epoch in range(10):

    train_loss = train(epoch, criterion, model, optimizer, train_loader)
    val_loss = validate(criterion, model, val_loader)
    losses["train"].append(train_loss)
    losses["val"].append(val_loss)

    plt.plot(losses["train"], label="training loss")
    plt.plot(losses["val"], label="validation loss")

    plt.legend()
    plt.pause(0.000001)
    plt.show()
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.315437
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 2.100761
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 1.003331
#
# Test set: Average loss: 0.0021, Accuracy: 6362/10000 (64%)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 1.114451
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.720303
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.848961
#
# Test set: Average loss: 0.0019, Accuracy: 6592/10000 (66%)
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.845658
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.787766
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.769059
#
# Test set: Average loss: 0.0014, Accuracy: 7343/10000 (73%)
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.732232
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.657944
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.702394
#
# Test set: Average loss: 0.0014, Accuracy: 7314/10000 (73%)
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.790274
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.584466
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.618804
#
# Test set: Average loss: 0.0012, Accuracy: 7656/10000 (77%)
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.617216
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.583735
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.540213
#
# Test set: Average loss: 0.0011, Accuracy: 7939/10000 (79%)
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.598550
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.667036
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.590332
#
# Test set: Average loss: 0.0011, Accuracy: 7923/10000 (79%)
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.509121
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.454797
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.511293
#
# Test set: Average loss: 0.0011, Accuracy: 8044/10000 (80%)
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.527372
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.493621
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.477079
#
# Test set: Average loss: 0.0011, Accuracy: 8009/10000 (80%)
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.569650
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.509721
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.429050
#
# Test set: Average loss: 0.0010, Accuracy: 8199/10000 (82%)

# %% [markdown]
# It may also be useful to visualize some qualitative examples of classification

# %%
with torch.no_grad():

    data, target = next(iter(val_loader))
    data, target = data.to(device), target.to(device)

    output = model(data)
    predictions = np.argmax(output.cpu().numpy(), axis=1).tolist()
    true = target.cpu().numpy().tolist()

    plt.figure(figsize=(16, 6))

    print("Correctly predicted: {}%".format(100*sum(p == t for p, t in zip(predictions, true))/len(predictions)) )

    for i in range(10):
        plt.subplot(2, 5, i + 1)
        image = data[i,...].cpu().numpy().reshape((28,28))
        plt.imshow(image, cmap="gray")
        plt.axis('off')
        plt.title('Predicted as {}\n True label is {}'.format(val_set.classes[predictions[i]], val_set.classes[true[i]], ))
# Out:
# Correctly predicted: 83.59375%

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 4**: Now repeat the same process, but flip the images horizontally before you run them through the model. Is your accuracy affected? Why?
#
# > Hint: Check out the `numpy.flip()` function at https://pytorch.org/docs/stable/generated/torch.flip.html
#
# </span>

# %%
# Your Code Here
@torch.no_grad()  # prevent this function from computing gradients
def validate(criterion, model, loader):

    val_loss = 0
    correct = 0

    model.eval()

    for data, target in loader:

        data = torch.flip(data, [3]) #FLIP

        data, target = data.to(device), target.to(device)

        output = model(data)
        loss = criterion(output, target)
        val_loss += loss.item()
        pred = output.data.max(1, keepdim=True)[1] # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()

    val_loss /= len(loader.dataset)
    accuracy = 100. * correct / len(loader.dataset)
    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        val_loss, correct, len(loader.dataset), accuracy))


    return val_loss


def train(epoch, criterion, model, optimizer, loader):

    total_loss = 0.0

    model.train()

    for batch_idx, (data, target) in enumerate(loader):

        optimizer.zero_grad()

        data = torch.flip(data, [3])

        data, target = data.to(device), target.to(device)

        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(loader.dataset),
                100. * batch_idx / len(loader), loss.item()))


        total_loss += loss.item()  #.item() is very important here? Why?

    return total_loss / len(loader.dataset)

# %%
torch.backends.cudnn.benchmark = True
learning_rate = 1e-2
lambda_l2 = 1e-5
momentum = 0.5
torch.manual_seed(0) # seed for reproductibility

output_size = 10  # there are 10 classes

model = CNN(6, output_size)

print(f"Number of parameters: {get_n_params(model)}")

# move model to gpu if available
model.to(device)

# nn package also has different loss functions.
# we use cross entropy loss for our classification task
criterion = torch.nn.CrossEntropyLoss() # https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html#torch.nn.CrossEntropyLoss

# we use the optim package to apply
# stochastic gradient descent for our parameter updates
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate, momentum=momentum, weight_decay=lambda_l2) # built-in L2
# Out:
# Number of parameters: 6422

# %%
losses = {"train": [], "val": []}
for epoch in range(10):

    train_loss = train(epoch, criterion, model, optimizer, train_loader)
    val_loss = validate(criterion, model, val_loader)
    losses["train"].append(train_loss)
    losses["val"].append(val_loss)

    plt.plot(losses["train"], label="training loss")
    plt.plot(losses["val"], label="validation loss")

    plt.legend()
    plt.pause(0.000001)
    plt.show()
# Out:
# Train Epoch: 0 [0/60000 (0%)]	Loss: 2.315316
# Train Epoch: 0 [25600/60000 (43%)]	Loss: 2.116703
# Train Epoch: 0 [51200/60000 (85%)]	Loss: 0.992848
#
# Test set: Average loss: 0.0021, Accuracy: 6274/10000 (63%)
# Train Epoch: 1 [0/60000 (0%)]	Loss: 1.125537
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.713696
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.844383
#
# Test set: Average loss: 0.0018, Accuracy: 6540/10000 (65%)
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.832290
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.785778
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.728107
#
# Test set: Average loss: 0.0015, Accuracy: 7235/10000 (72%)
# Train Epoch: 3 [0/60000 (0%)]	Loss: 0.779935
# Train Epoch: 3 [25600/60000 (43%)]	Loss: 0.689035
# Train Epoch: 3 [51200/60000 (85%)]	Loss: 0.681795
#
# Test set: Average loss: 0.0014, Accuracy: 7331/10000 (73%)
# Train Epoch: 4 [0/60000 (0%)]	Loss: 0.774016
# Train Epoch: 4 [25600/60000 (43%)]	Loss: 0.580663
# Train Epoch: 4 [51200/60000 (85%)]	Loss: 0.634975
#
# Test set: Average loss: 0.0013, Accuracy: 7610/10000 (76%)
# Train Epoch: 5 [0/60000 (0%)]	Loss: 0.598380
# Train Epoch: 5 [25600/60000 (43%)]	Loss: 0.555216
# Train Epoch: 5 [51200/60000 (85%)]	Loss: 0.526352
#
# Test set: Average loss: 0.0012, Accuracy: 7855/10000 (79%)
# Train Epoch: 6 [0/60000 (0%)]	Loss: 0.595620
# Train Epoch: 6 [25600/60000 (43%)]	Loss: 0.637502
# Train Epoch: 6 [51200/60000 (85%)]	Loss: 0.640173
#
# Test set: Average loss: 0.0011, Accuracy: 7871/10000 (79%)
# Train Epoch: 7 [0/60000 (0%)]	Loss: 0.510663
# Train Epoch: 7 [25600/60000 (43%)]	Loss: 0.451845
# Train Epoch: 7 [51200/60000 (85%)]	Loss: 0.486967
#
# Test set: Average loss: 0.0011, Accuracy: 8049/10000 (80%)
# Train Epoch: 8 [0/60000 (0%)]	Loss: 0.498444
# Train Epoch: 8 [25600/60000 (43%)]	Loss: 0.472203
# Train Epoch: 8 [51200/60000 (85%)]	Loss: 0.482488
#
# Test set: Average loss: 0.0011, Accuracy: 7932/10000 (79%)
# Train Epoch: 9 [0/60000 (0%)]	Loss: 0.595058
# Train Epoch: 9 [25600/60000 (43%)]	Loss: 0.491779
# Train Epoch: 9 [51200/60000 (85%)]	Loss: 0.425600
#
# Test set: Average loss: 0.0010, Accuracy: 8237/10000 (82%)

# %%
with torch.no_grad():

    data, target = next(iter(val_loader))
    data, target = data.to(device), target.to(device)

    output = model(data)
    predictions = np.argmax(output.cpu().numpy(), axis=1).tolist()
    true = target.cpu().numpy().tolist()

    plt.figure(figsize=(16, 6))

    print("Correctly predicted: {}%".format(100*sum(p == t for p, t in zip(predictions, true))/len(predictions)) )

    for i in range(10):
        plt.subplot(2, 5, i + 1)
        image = data[i,...].cpu().numpy().reshape((28,28))
        plt.imshow(image, cmap="gray")
        plt.axis('off')
        plt.title('Predicted as {}\n True label is {}'.format(val_set.classes[predictions[i]], val_set.classes[true[i]], ))
# Out:
# Correctly predicted: 84.5703125%

# %% [markdown]
# ---
# The accuracy results are as follows:
# - **Without flipping:** 83.59%
# - **With flipping:** 84.57%
#
# The improvement in accuracy suggests that applying a horizontal flip benefits the model’s performance.
#
# This is because maintaining **consistency between the training and validation sets** is crucial. When both sets undergo the same transformation, their data distributions remain similar, allowing the model to generalize better.
#
# Additionally, horizontal flipping is a **data augmentation** technique that helps the model learn more diverse features. By including flipped images, the model becomes more **rotation-invariant**, improving its ability to recognize objects from different perspectives.
#
# ---

# %% [markdown]
# ## Visualising Filters

# %% [markdown]
# One thing that would be interesting to visualise is the weights of the filters. To do so, we just need to access the weights of the convolutional layer of interest, and turn them into images. Here's an example for the first convolutional layer.

# %%
weight = model.conv1.weight.data.cpu().numpy()

# Display the filters
fig, ax = plt.subplots(1, weight.shape[0], figsize=(5, 5))

for i in range(weight.shape[0]):
    ax[i].imshow(weight[i, 0], cmap='gray') # show the first (and only) channel weights
    ax[i].axes.get_xaxis().set_visible(False)
    ax[i].axes.get_yaxis().set_visible(False)

# %% [markdown]
# ## Visualising Activation Maps

# %% [markdown]
# Another thing would be to visualise the activations of a convolutional layer for a specific image when it goes through the model. To do so, we need to somehow capture the output of the convolutional layer during the forward pass. This can be done with the function `nn.Conv2d.register_forward_hook()`. This function accepts as argument a callback function that will be called by the model when the forward pass takes place.
#
# See some more information about this function below:

# %%
nn.Conv2d.register_forward_hook??

# %% [markdown]
# To try this out, we will defineby hand a toy model that does edge detection, as well as a couple of images to apply it on

# %%
simpleEdgeDetector = nn.Conv2d(in_channels=1, out_channels=2, kernel_size=3)

# Define a vertical edge detector filter
simpleEdgeDetector.weight.data[0, 0] = torch.tensor([  [1., 0., -1.],
                                                   [1., 0., -1.],
                                                   [1., 0., -1.]])

# Define an horizontal edge detector filter
simpleEdgeDetector.weight.data[1, 0] = torch.tensor([  [1., 1., 1.],
                                                   [0., 0., 0.],
                                                   [-1., -1., -1.]])

simpleEdgeDetector.bias.data = torch.zeros(2)

simpleEdgeDetector = simpleEdgeDetector.to(device)


fakeImageBatch = torch.zeros(2, 1, 26, 26) # create a batch of two black images of (10, 10)
fakeImageBatch[0,0,3,3] = 1 # Paint white pixel (3, 3)
fakeImageBatch[1,0,6,6] = 1 # Paint white pixel (6, 6)

# Show the images
fig, ax = plt.subplots(2, 1, figsize=(5, 5))
ax[0].imshow(fakeImageBatch[0,0], cmap='gray')
ax[1].imshow(fakeImageBatch[1,0], cmap='gray')

# %% [markdown]
# Let's also define some helper functions to plot a grid of activation maps given the output of a convolution layer.

# %%
def showImage(img, ax):
    # convert the tensor to numpy
    out = img.numpy()
    # Bring to the 0-255 range
    out = out - out.min()
    out = out / out.max()
    out = out * 255
    out = out.astype('uint8')
    # Plot image
    ax.axes.get_xaxis().set_visible(False)
    ax.axes.get_yaxis().set_visible(False)
    ax.imshow(out, cmap='gray')

def showConvMap(conv_map):
    # Create a grid of images
    h = conv_map.shape[0] # = number of images in the batch
    w = conv_map.shape[1] # = number of activation maps per image
    fig, ax = plt.subplots(h, w, figsize=(10, 10))

    # Plot activation maps
    for i in range(conv_map.shape[0]):
        for j in range(conv_map.shape[1]):
            showImage(conv_map[i][j], ax[i, j])

    fig.tight_layout()

# %% [markdown]
# Now we can define our hook function, which just calls `showConvMap()` to plot the output activation maps for all the images of our batch and all the filters of this layer.

# %%
def hook_ShowOutput(module, input, output):
    print("Output shape:", output.shape)
    showConvMap(output.cpu())

fakeImageBatch = fakeImageBatch.to(device)

with torch.no_grad():
    handle = simpleEdgeDetector.register_forward_hook(hook_ShowOutput)
    embed = simpleEdgeDetector(fakeImageBatch)
    handle.remove()
# Out:
# Output shape: torch.Size([2, 2, 24, 24])

# %% [markdown]
# <br>
# <span style="color:blue">
#
# **Exercise 5**: Visualize the feature (activation) maps of the first and last convolutional layers of our CNN model for 10 images of your validation set. Use the code provided before as the basis for your visualisation. What conclusions can you draw?
#
# </span>

# %%
# Your Code Here
def showConvMap(conv_map, num_images):
    h = min(conv_map.shape[0], num_images)  # Number of images in the batch, limited by num_images
    w = conv_map.shape[1]  # Number of activation maps per image
    fig, ax = plt.subplots(h, w, figsize=(10, 10))

    for i in range(h):
        for j in range(w):
            showImage(conv_map[i][j], ax[i, j])

    fig.tight_layout()
def visualize_feature_maps(model, dataloader, num_images, layers):
    hooks = []

    def hook_ShowOutput(module, input, output):
        print("Output shape:", output.shape)
        showConvMap(output.cpu().detach(), num_images)

    for layer in layers:
        handle = layer.register_forward_hook(hook_ShowOutput)
        hooks.append(handle)

    with torch.no_grad():
        count = 0
        for images, labels in dataloader:
            images = images.to(device)
            model(images)
            count += 1
            if count >= num_images:
                break
    for hook in hooks:
        hook.remove()
# Get th first and last convolutional layers
first_conv_layer = model.conv1
last_conv_layer = model.conv2

# Visualize the feature maps for 10 images from the validation set
num_images = 10

# %%
visualize_feature_maps(model, val_loader, num_images, [first_conv_layer])
# Out:
# Output shape: torch.Size([512, 6, 24, 24])
# Output shape: torch.Size([512, 6, 24, 24])
# Output shape: torch.Size([512, 6, 24, 24])
# Output shape: torch.Size([512, 6, 24, 24])
# Output shape: torch.Size([512, 6, 24, 24])
# Output shape: torch.Size([512, 6, 24, 24])
# Output shape: torch.Size([512, 6, 24, 24])
# Output shape: torch.Size([512, 6, 24, 24])
# Output shape: torch.Size([512, 6, 24, 24])
# Output shape: torch.Size([512, 6, 24, 24])

# %%
visualize_feature_maps(model, val_loader, num_images, [last_conv_layer])
# Out:
# Output shape: torch.Size([512, 6, 8, 8])
# Output shape: torch.Size([512, 6, 8, 8])
# Output shape: torch.Size([512, 6, 8, 8])
# Output shape: torch.Size([512, 6, 8, 8])
# Output shape: torch.Size([512, 6, 8, 8])
# Output shape: torch.Size([512, 6, 8, 8])
# Output shape: torch.Size([512, 6, 8, 8])
# Output shape: torch.Size([512, 6, 8, 8])
# Output shape: torch.Size([512, 6, 8, 8])
# Output shape: torch.Size([512, 6, 8, 8])

# %% [markdown]
# ---
# At the beginning, the first convolutional layer focuses on small, specific parts of the image, detecting fine details like edges and textures. As we move to the second layer, the model starts recognizing larger patterns, such as shapes and structures, giving a more general understanding of the image. This happens because, with each layer, the area that the kernels analyze increases, allowing the model to see a broader part of the image at once. As a result, deeper layers capture the full context of the image, making the model better at recognizing complex patterns and objects.
#
#
#
# ---
